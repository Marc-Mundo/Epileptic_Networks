# %%
# Jupyter notebook magic to reload modules
# %load_ext autoreload
# %autoreload 2

# %%
import sys

sys.path.append(
    "../",
)  # path to the src with the functions

# %%
import pickle

# Path to the pickle file
pkl_path_1 = "../data/Data03_model_validation/08.pkl"  # Baseline at 20X external input
# Load the pickle file
# load path 1
try:
    with open(pkl_path_1, "rb") as file:
        data = pickle.load(file)
    print("Data loaded successfully.")
except Exception as e:
    print("Error loading the file:", e)
# Out:
# Data loaded successfully.

# %%
import matplotlib.pyplot as plt
from src.SanjayCode import scatter_plot

simdata = data["simData"]
scatter_plot(simdata)
# plt.title("Baseline at 20X external input")
