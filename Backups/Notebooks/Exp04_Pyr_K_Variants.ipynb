# %% [markdown]
# # Imports

# %%
import sys

sys.path.append(
    "/home/Marc/neuromics/Marc_Internship"
)  # path to the code with the functions

# %% [markdown]
# # Load data

# %%
# Import load function
from src.SanjayCode import load

# Path to data directory
data_path = "../data/Data06_Pyr_K_Variants/"

# Define the runs to be analyzed and the corresponding labels
my_runs = [
    "K_0.5",
    "K_0.6",
    "K_0.7",
    "K_0.8",
    "K_0.9",
    "K_1.0",
    "K_1.1",
    "K_1.2",
    "K_1.3",
    "K_1.4",
    "K_1.5",
]

# Load the data
data = load(data_path)
# Out:
# dict_keys([])
# {}
# numprocs=1
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.5/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.5/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.5/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.5/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.5/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.7/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.7/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.7/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.7/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.7/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.8/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.8/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.8/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.8/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.8/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.4/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.4/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.4/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.4/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.4/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.6/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.6/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.6/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.6/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.6/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.9/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.9/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.9/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.9/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_0.9/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.3/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.3/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.3/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.3/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.3/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.0/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.0/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.0/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.0/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.0/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.5/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.5/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.5/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.5/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.5/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.2/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.2/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.2/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.2/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.2/03.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.1/04.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.1/02.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.1/01.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.1/00.pkl
# Loaded: ../data/Data06_Pyr_K_Variants/K_1.1/03.pkl

# %%
# Check the data structure, can be different depending on the output of the simulation
print(data.keys())  # conditions in the data
print(data["K_0.5"].keys())  # first condition in the data
print(data["K_0.5"]["00"].keys())  # first pickle file in the NA condition
# Out:
# dict_keys(['K_0.5', 'K_0.7', 'K_0.8', 'K_1.4', 'K_0.6', 'K_0.9', 'K_1.3', 'K_1.0', 'K_1.5', 'K_1.2', 'K_1.1'])
# dict_keys(['04', '02', '01', '00', '03'])
# dict_keys(['netParams', 'simData'])

# %% [markdown]
# # Process data

# %%
# Import process_data function
from src.SanjayCode import process_data

# Dictionary to store results for each condition and run
results = {}

# Iterate over each condition and run
for condition, runs in data.items():
    results[condition] = {}
    for run, simData in runs.items():
        print(f"Processing {condition}, run {run}")
        results[condition][run] = process_data(simData["simData"])
# Out:
# Processing K_0.5, run 04
# Processing K_0.5, run 02
# Processing K_0.5, run 01
# Processing K_0.5, run 00
# Processing K_0.5, run 03
# Processing K_0.7, run 04
# Processing K_0.7, run 02
# Processing K_0.7, run 01
# Processing K_0.7, run 00
# Processing K_0.7, run 03
# Processing K_0.8, run 04
# Processing K_0.8, run 02
# Processing K_0.8, run 01
# Processing K_0.8, run 00
# Processing K_0.8, run 03
# Processing K_1.4, run 04
# Processing K_1.4, run 02
# Processing K_1.4, run 01
# Processing K_1.4, run 00
# Processing K_1.4, run 03
# Processing K_0.6, run 04
# Processing K_0.6, run 02
# Processing K_0.6, run 01
# Processing K_0.6, run 00
# Processing K_0.6, run 03
# Processing K_0.9, run 04
# Processing K_0.9, run 02
# Processing K_0.9, run 01
# Processing K_0.9, run 00
# Processing K_0.9, run 03
# Processing K_1.3, run 04
# Processing K_1.3, run 02
# Processing K_1.3, run 01
# Processing K_1.3, run 00
# Processing K_1.3, run 03
# Processing K_1.0, run 04
# Processing K_1.0, run 02
# Processing K_1.0, run 01
# Processing K_1.0, run 00
# Processing K_1.0, run 03
# Processing K_1.5, run 04
# Processing K_1.5, run 02
# Processing K_1.5, run 01
# Processing K_1.5, run 00
# Processing K_1.5, run 03
# Processing K_1.2, run 04
# Processing K_1.2, run 02
# Processing K_1.2, run 01
# Processing K_1.2, run 00
# Processing K_1.2, run 03
# Processing K_1.1, run 04
# Processing K_1.1, run 02
# Processing K_1.1, run 01
# Processing K_1.1, run 00
# Processing K_1.1, run 03

# %% [markdown]
# # Data structure

# %%
print(results.keys())
print(results["K_0.5"].keys())
print(results["K_0.5"]["00"].keys())
# Out:
# dict_keys(['K_0.5', 'K_0.7', 'K_0.8', 'K_1.4', 'K_0.6', 'K_0.9', 'K_1.3', 'K_1.0', 'K_1.5', 'K_1.2', 'K_1.1'])
# dict_keys(['04', '02', '01', '00', '03'])
# dict_keys(['pyr_mean', 'bwb_mean', 'olm_mean', 'pyr_std', 'bwb_std', 'olm_std', 'lfps', 'gamma_frequencies', 'theta_frequencies', 'mean_gamma_power', 'mean_theta_power'])

# %%
# Name of variant
variant_type = "Pyr Potassium conductance (times baseline)"  # of pyramidal cells

# Conditions for potassium conductance
k_variants = {
    "K_0.5": 0.5,
    "K_0.6": 0.6,
    "K_0.7": 0.7,
    "K_0.8": 0.8,
    "K_0.9": 0.9,
    "K_1.0": 1.0,
    "K_1.1": 1.1,
    "K_1.2": 1.2,
    "K_1.3": 1.3,
    "K_1.4": 1.4,
    "K_1.5": 1.5,
}

# %% [markdown]
# # Analysis

# %%
# Plot 1: Individual Cell Firing Rates per Population
from src.SanjayCode import plot_firing_rates

# Call the plotting function
plot_firing_rates(results, k_variants, variant_type)

# %%
# Plot 2: Change in Theta and Gamma frequencies
from src.SanjayCode import plot_theta_gamma_frequencies

# Call the plotting function
plot_theta_gamma_frequencies(results, k_variants, variant_type)

# %%
# Plot 3: Change in Theta and Gamma power
from src.SanjayCode import plot_theta_gamma_power

# Call the plotting function
plot_theta_gamma_power(results, k_variants, variant_type)
